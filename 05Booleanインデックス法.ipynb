# %% [markdown]
# # Chapter 5: Booleanインデックス法
#
# ## レシピ
# * [Boolean統計量の計算](#レシピ33-Boolean統計量の計算)
# * [複数のBoolean条件の構築](#レシピ34-複数のBoolean条件の構築)
# * [Booleanインデックス法によるフィルタリング](#レシピ35-Booleanインデックス法によるフィルタリング)
# * [インデックス選択によるBooleanインデックス法の代用](#レシピ36-インデックス選択によるBooleanインデックス法の代用)
# * [重複のないインデックスとソートしたインデックスによる選択](#レシピ37-重複のないインデックスとソートしたインデックスによる選択)
# * [株価見通しの計算](#レシピ38-株価見通しの計算)
# * [SQLのWHERE節の翻訳](#レシピ39-SQLのWHERE節の翻訳)
# * [株式収益率の正規度判定](#レシピ40-株式収益率の正規度判定)
# * [queryメソッドによるBooleanインデックス法の読みやすさ改善](#レシピ41-queryメソッドによるBooleanインデックス法の読みやすさ改善)
# * [whereメソッドによるSeriesの保持](#レシピ42-whereメソッドによるSeriesの保持)
# * [DataFrameの行のマスキング](#レシピ43-DataFrameの行のマスキング)
# * [Boolean, 整数位置, ラベルによる選択](#レシピ44-Boolean,整数位置,ラベルによる選択)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
pd.options.display.max_columns = 50

# %% [markdown]
# # レシピ33 Boolean統計量の計算

# %% [markdown]
# #### データカラムに対して条件を当てはめ、その結果の要約統計量を計算する

# %%
# movieデータセットを読み込む
movie = pd.read_csv("data/movie.csv", index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# 映画の上演時間が2時間を超えるかどうか比較演算子を使って調べる
movie_2hours = movie['duration'] > 120
movie_2hours.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
# 2時間を超える映画の本数を調べる
movie_2hours.sum()
# Out:
# 1039

# %%
# 2時間を超える映画のパーセントを求めるにはmeanをつかう
movie_2hours.mean()
# Out:
# 0.2113506916192026

# %%
# Boolean条件は欠損値に対してFalseを返す。最初に欠損値を削除してから条件を評価する
movie['duration'].dropna().gt(120).mean()   # gtは＞と同じ
# Out:
# 0.21199755152009794

# %%
# describeでBoolean Seriesの要約統計量を出力する
movie_2hours.describe()
# Out:
# count      4916
# unique        2
# top       False
# freq       3877
# Name: duration, dtype: object

# %%
# Boolean Seriesの平均がTrue値のパーセントであることの証明
movie_2hours.value_counts(normalize=True)
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64

# %% [markdown]
# # レシピ34 複数のBoolean条件の構築

# %% [markdown]
# #### pandasの論理式には&, | , ~  (and, or, not)を使う

# %%
# 選択基準それぞれによるBooleanのSeriesで表す集合を格納する変数を作る
criteria1 = movie.imdb_score > 8
criteria2 = movie.content_rating == 'PG-13'
criteria3 = (movie.title_year < 2000) | (movie.title_year >= 2010)
criteria2.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: content_rating, dtype: bool

# %%
# 基準を組み合わせて、１つのBooleanのSeriesにする
criteria_final = criteria1 & criteria2 & criteria3
criteria_final.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %% [markdown]
# # レシピ35 Booleanインデックス法によるフィルタリング

# %%
#　1つ目の基準集合を作る
crit_a1 = movie.imdb_score > 8
crit_a2 = movie.content_rating == 'PG-13'
crit_a3 = (movie.title_year < 2000) | (movie.title_year >= 2009)
final_crit_a = crit_a1 & crit_a2 & crit_a3

# %%
# 2つ目の基準集合を作る
crit_b1 = movie.imdb_score < 5
crit_b2 = movie.content_rating == 'R'
crit_b3 = (movie.title_year >=2000) | (movie.title_year <= 2010)
final_crit_b = crit_b1 & crit_b2 & crit_b3

# %%
# or演算子を使って２つの基準集合の和を取る
final_crit_all = final_crit_a | final_crit_b
final_crit_all.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
# データフィルタリングするためにインデックス演算子に渡す
movie[final_crit_all].head()
# Out:
#                             color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises       Color  Christopher Nolan                   813.0
# The Avengers                Color        Joss Whedon                   703.0
# Captain America: Civil War  Color      Anthony Russo                   516.0
# The Lovers                  Color       Roland Joffé                    10.0
# Guardians of the Galaxy     Color         James Gunn                   653.0
#
#                             duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises          164.0                  22000.0
# The Avengers                   173.0                      0.0
# Captain America: Civil War     147.0                     94.0
# The Lovers                     109.0                    596.0
# Guardians of the Galaxy        121.0                    571.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# ...

# %%
# locで行とカラムの両方をフィルタリングして結果を確認する
cols = ['imdb_score', 'content_rating', 'title_year']
movie_filtered = movie.loc[final_crit_all,cols]
movie_filtered.head()
# Out:
#                             imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises              8.5          PG-13      2012.0
# The Avengers                       8.1          PG-13      2012.0
# Captain America: Civil War         8.2          PG-13      2016.0
# The Lovers                         4.5              R      2015.0
# Guardians of the Galaxy            8.1          PG-13      2014.0

# %%
# 短い論理式を組み合わせる代わりに長い論理式１つで済ますこともできる
final_crit_a2 = (movie.imdb_score > 8) & \
                (movie.content_rating == 'PG-13') & \
                ((movie.title_year < 2000) | (movie.title_year > 2009))
final_crit_a2.equals(final_crit_a)
# Out:
# True

# %% [markdown]
# # レシピ36 インデックス選択によるBooleanインデックス法の代用

# %% [markdown]
# #### Booleanインデックス法とインデックス法とインデックス選択での性能を比較する

# %%
college = pd.read_csv('data/college.csv')

# %%
college[college['STABBR'] == 'TX'].head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# 3610        0.0         1     530.0     545.0           0.0  3572.0
# 3611        0.0         0       NaN       NaN           0.0  4682.0
# 3612        0.0         0       NaN       NaN           0.0  9346.0
# 3613        0.0         0       NaN       NaN           0.0  3825.0
# 3614        0.0         0     475.0     490.0           0.0  5290.0
#
#       UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# ...

# %%
# インデックス選択を行う為、STABBRカラムをインデックスにする
college2 = college.set_index('STABBR')
college2.loc['TX'].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  UGDS_WHITE  \
# STABBR
# TX             1     530.0     545.0           0.0  3572.0      0.6739
# TX             0       NaN       NaN           0.0  4682.0      0.5126
# TX             0       NaN       NaN           0.0  9346.0      0.5104
# TX             0       NaN       NaN           0.0  3825.0      0.5854
# TX             0     475.0     490.0           0.0  5290.0      0.5225
#
# ...

# %%
#両方の速度を比較
# %timeit college[college['STABBR'] == 'TX']
# Out:
# 971 µs ± 49.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 437 µs ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# インデックスの設定の手間を考慮する必要があるので、その時間も計測する
# %timeit college2 = college.set_index('STABBR')
# Out:
# 1.42 ms ± 66 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Boolen選択で救数選択する場合はisinメソッドを使う
states = ['TX', 'CA', 'NY']
college[college['STABBR'].isin(states)]
# Out:
#                                                  INSTNM              CITY  \
# 192                           Academy of Art University     San Francisco
# 193              ITT Technical Institute-Rancho Cordova    Rancho Cordova
# 194      Academy of Chinese Culture and Health Sciences           Oakland
# 195            The Academy of Radio and TV Broadcasting  Huntington Beach
# 196                Avalon School of Cosmetology-Alameda           Alameda
# ...                                                 ...               ...
# 7528                           WestMed College - Merced            Merced
# 7529                                    Vantage College           El Paso
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %% [markdown]
# # レシピ37 重複のないインデックスとソートしたインデックスによる選択

# %% [markdown]
# #### 重複がないか、ソートされたインデックスを使ってインデックス選択の性能を上げる

# %%
# STABBRがインデックスの別のDFを作りインデックスがソートされているか確認する
college2 = college.set_index('STABBR')
college2.index.is_monotonic
# Out:
# False

# %%
# college2のインデックスをソートして別オブジェクトを作成
college3 = college2.sort_index()
college3.index.is_monotonic
# Out:
# True

# %%
# 3つの時間を計測する
# %timeit college[college['STABBR']=='TX']
# Out:
# 927 µs ± 20 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 452 µs ± 19.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college3.loc['TX']
# Out:
# 153 µs ± 3.69 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# インデックスに重複がない場合を調べるため、校名をインデックスに使う
college_unique = college.set_index('INSTNM')
college_unique.index.is_unique
# Out:
# True

# %%
# Booleanインデックス法でStanford Universityを選ぶ
college[college['INSTNM'] == 'Stanford University']
# Out:
#                    INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4217  Stanford University  Stanford     CA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  UGDS_WHITE  \
# 4217         0     730.0     745.0           0.0  7018.0      0.3752
#
#       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# 4217      0.0591     0.1607      0.1979     0.0114     0.0038     0.1067
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4217    0.0819     0.0031       0.0         1   0.1556    0.1256   0.0401
#
#      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# 4217           86000              12782

# %%
# インデックス選択でStanford Universityを選ぶ
college_unique.loc['Stanford University']
# Out:
# CITY                  Stanford
# STABBR                      CA
# HBCU                         0
# MENONLY                      0
# WOMENONLY                    0
# RELAFFIL                     0
# SATVRMID                   730
# SATMTMID                   745
# DISTANCEONLY                 0
# UGDS                      7018
# UGDS_WHITE              0.3752
# UGDS_BLACK              0.0591
# UGDS_HISP               0.1607
# UGDS_ASIAN              0.1979
# UGDS_AIAN               0.0114
# UGDS_NHPI               0.0038
# UGDS_2MOR               0.1067
# UGDS_NRA                0.0819
# UGDS_UNKN               0.0031
# PPTUG_EF                     0
# CURROPER                     1
# PCTPELL                 0.1556
# PCTFLOAN                0.1256
# UG25ABV                 0.0401
# MD_EARN_WNE_P10          86000
# GRAD_DEBT_MDN_SUPP       12782
# Name: Stanford University, dtype: object

# %%
# 時間を計測する
# %timeit college[college['INSTNM'] == 'Stanford University']
# Out:
# 862 µs ± 14.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college_unique.loc['Stanford University']
# Out:
# 142 µs ± 6.36 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# 複数カラムを連結してインデックスにする事も可能
college.index = college['CITY'] + ',' + college['STABBR']
college = college.sort_index()
college.head()
# Out:
#                                 INSTNM      CITY STABBR  HBCU  MENONLY  \
# ARTESIA,CA           Angeles Institute   ARTESIA     CA   0.0      0.0
# Aberdeen,SD       Presentation College  Aberdeen     SD   0.0      0.0
# Aberdeen,SD  Northern State University  Aberdeen     SD   0.0      0.0
# Aberdeen,WA       Grays Harbor College  Aberdeen     WA   0.0      0.0
# Abilene,TX   Hardin-Simmons University   Abilene     TX   0.0      0.0
#
#              WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# ARTESIA,CA         0.0         0       NaN       NaN           0.0   114.0
# Aberdeen,SD        0.0         1     440.0     480.0           0.0   705.0
# Aberdeen,SD        0.0         0     480.0     475.0           0.0  1693.0
# Aberdeen,WA        0.0         0       NaN       NaN           0.0  1121.0
# Abilene,TX         0.0         1     508.0     515.0           0.0  1576.0
#
#              UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# ...

# %%
# Booleanインデックス法を使わす、指定した都市と州の組み合わせで大学を選べる
college.loc['Miami,FL'].head()
# Out:
#                                              INSTNM   CITY STABBR  HBCU  \
# Miami,FL        New Professions Technical Institute  Miami     FL   0.0
# Miami,FL               Management Resources College  Miami     FL   0.0
# Miami,FL                   Strayer University-Doral  Miami     FL   NaN
# Miami,FL                   Keiser University- Miami  Miami     FL   NaN
# Miami,FL  George T Baker Aviation Technical College  Miami     FL   0.0
#
#           MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# Miami,FL      0.0        0.0         0       NaN       NaN           0.0
# Miami,FL      0.0        0.0         0       NaN       NaN           0.0
# Miami,FL      NaN        NaN         1       NaN       NaN           NaN
# Miami,FL      NaN        NaN         1       NaN       NaN           NaN
# Miami,FL      0.0        0.0         0       NaN       NaN           0.0
#
#            UGDS  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  \
# ...

# %% [markdown]
# # レシピ38 株価見通しの計算

# %% [markdown]
# #### Booleanインデックス法を使って、株価の終値の最高及び最低10%のSeriesを抽出する

# %%
# Schlumberger(SLB)の株価データを読み込み、DataカラムをindexにしてDatetimeIndexに変換する
slb = pd.read_csv('data/slb_stock.csv', index_col='Date',parse_dates=['Date'])
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
# 終値をSeriesで選択し、要約統計量を表示
slb_close = slb['Close']
slb_summary = slb_close.describe(percentiles=[.1, .9])
slb_summary
# Out:
# count    1895.000000
# mean       79.121905
# std        11.767802
# min        51.750000
# 10%        64.892000
# 50%        78.000000
# 90%        93.248000
# max       117.950000
# Name: Close, dtype: float64

# %%
# Booleanインデックス法を使って、最高及び最低の10パーセンタイル内の終値を選ぶ
upper_10 = slb_summary.loc['90%']
lower_10 = slb_summary.loc['10%']
criteria = (slb_close < lower_10) | (slb_close > upper_10)
slb_top_bottom_10 = slb_close[criteria]

# %%
# フィルタしたSeriesを灰色で黒の終値の上にプロットする
slb_close.plot(color='black', figsize=(12,6))
slb_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')
xmin = criteria.index[0]
xmax = criteria.index[-1]
plt.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='black')

# %%
print(xmin)
# Out:
# 2010-01-04 00:00:00

# %%
# matplotlibのfill_betweenを使うと2つの線で挟まれた領域を塗りつぶす
slb_close.plot(color='black', figsize=(12,6))
plt.hlines(y=[lower_10, upper_10],
          xmin=xmin, xmax=xmax,color='lightgray')
plt.fill_between(x=criteria.index, y1=lower_10,
                 y2=slb_close.values, color='black')
plt.fill_between(x=criteria.index,y1=lower_10,
                 y2=slb_close, where=slb_close < lower_10,color='lightgray')

# %% [markdown]
# # レシピ39 SQLのWHERE節の翻訳

# %%
# employeeデータセットをDataFrameに読み込む
employee = pd.read_csv('data/employee.csv')

# %%
# 対象カラムを確認する
employee.DEPARTMENT.value_counts().head()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Name: DEPARTMENT, dtype: int64

# %%
employee.BASE_SALARY.describe().astype(int)
# Out:
# count      1886
# mean      55767
# std       21693
# min       24960
# 25%       40170
# 50%       54461
# 75%       66614
# max      275000
# Name: BASE_SALARY, dtype: int32

# %%
# フィルタリング基準を書く
depts = ['Houston Police Department-HPD',
         'Houston Fire Department (HFD)']
criteria_dept = employee.DEPARTMENT.isin(depts)
criteria_gender = employee.GENDER == 'Female'
criteria_sal = (employee.BASE_SALARY >= 80000) & (employee.BASE_SALARY <= 120000)

# %%
# すべてのBoolean Seriesを組み合わせる
criteria_fainal = (criteria_dept & criteria_gender & criteria_sal)

# %%
# 最終的なフィルタ基準に合致する行だけ選ぶ
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']
employee.loc[criteria_fainal, select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
# Seriesにはbetweenメソッドがありcriteria_salを次のようにかける
criteria_sal = employee.BASE_SALARY.between(8000, 120000)

# %%
# 最も人数の多い上位5部門を除く
top_5_depts = employee.DEPARTMENT.value_counts().index[:5]
criteria = ~employee.DEPARTMENT.isin(top_5_depts)
employee[criteria]
# Out:
#       UNIQUE_ID                     POSITION_TITLE  \
# 0             0        ASSISTANT DIRECTOR (EX LVL)
# 1             1                  LIBRARY ASSISTANT
# 4             4                        ELECTRICIAN
# 18           18           MAINTENANCE MECHANIC III
# 32           32                  SENIOR ACCOUNTANT
# ...         ...                                ...
# 1976       1976         SENIOR SIDELOADER OPERATOR
# 1983       1983          ADMINISTRATIVE SPECIALIST
# 1985       1985                       TRUCK DRIVER
# 1988       1988  SENIOR ASSISTANT CITY ATTORNEY II
# 1990       1990    BUILDING MAINTENANCE SUPERVISOR
#
#                        DEPARTMENT  BASE_SALARY                       RACE  \
# 0     Municipal Courts Department     121862.0            Hispanic/Latino
# 1                         Library      26125.0            Hispanic/Latino
# 4     General Services Department      56347.0                      White
# ...

# %% [markdown]
# # レシピ40 株価収益率の正規度判定

# %% [markdown]
# #### Amazonの日次株式収益率の求めかたとそれが正規分布に従ってるか確認する

# %%
# amazonの株価データをロードする
amzn = pd.read_csv('data/amzn_stock.csv', index_col='Date',
                   parse_dates=['Date'])
amzn.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2010-01-04  136.25  136.61  133.14  133.90   7600543
# 2010-01-05  133.43  135.48  131.81  134.69   8856456
# 2010-01-06  134.60  134.73  131.65  132.25   7180977
# 2010-01-07  132.01  132.32  128.80  130.00  11030124
# 2010-01-08  130.56  133.68  129.03  133.52   9833829

# %%
# 終値のSeriesを作成し、pct_changeメソッドで日次収益率を取得
amzn_daily_return = amzn.Close.pct_change()
amzn_daily_return.head()
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.005900
# 2010-01-06   -0.018116
# 2010-01-07   -0.017013
# 2010-01-08    0.027077
# Name: Close, dtype: float64

# %%
# 欠損値を削除し、ヒストグラムをプロットして分布を調べる
amzn_daily_return = amzn_daily_return.dropna()
amzn_daily_return.hist(bins=20)

# %%
# 平均と標準偏差を求める
mean = amzn_daily_return.mean()
std = amzn_daily_return.std()

# %%
# 行ごとにz-scoreの絶対値を計算。z-scoreは平均から標準偏差でいくつ乖離しているか示す
abs_z_score = amzn_daily_return.sub(mean).abs().div(std)

# %%
# 日次収益率が平均から1σ、2σ、3σに収まるパーセントを計算する
pcts = [abs_z_score.lt(i).mean() for i in range(1,4)]
print('{:.3f} fall within 1 standard deviation.{:.3f} within 2 and {:.3f} within 3'.format(*pcts))
# Out:
# 0.787 fall within 1 standard deviation.0.956 within 2 and 0.985 within 3

# %%
# 上記を関数化する

def test_return_normality(stock_data):
    close = stock_data['Close']
    daily_return = close.pct_change().dropna()
    daily_return.hist(bins=20)
    mean = daily_return.mean()
    std = daily_return.std()
    abs_z_score = abs(daily_return - mean) / std
    pcts = [abs_z_score.lt(i).mean() for i in range(1,4)]
    
    print('{:.3f} fall within 1 standard deviation.{:.3f} within 2 and {:.3f} within 3'.format(*pcts))

# %%
slb = pd.read_csv('data/slb_stock.csv', index_col='Date',
                  parse_dates=['Date'])
test_return_normality(slb)
# Out:
# 0.742 fall within 1 standard deviation.0.946 within 2 and 0.986 within 3

# %% [markdown]
# # レシピ41 queryメソッドによるBooleanインデックス法の読みやすさ改善

# %% [markdown]
# #### レシピ39をDataFrameのqueryメソッドを使って書き直す

# %%
# 部門とカラムを指定する
depts = ['Houston Police Department-HPD',
         'Houston Fire Department (HFD)']
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']

# %%
# クエリ文字列を作り、メソッドを実行する
qs = "DEPARTMENT in @depts " \
         "and GENDER == 'Female' " \
         "and 80000 <= BASE_SALARY <= 120000"
emp_filtered = employee.query(qs)
emp_filtered[select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
# 人数が多い上位10部門以外の女性従業員を求める
top10_depts = employee.DEPARTMENT.value_counts().index[:10].tolist()
qs = "DEPARTMENT not in @top10_depts and GENDER == 'Female'"
employee_filtered2 = employee.query(qs)
employee_filtered2[['DEPARTMENT', 'GENDER']].head()
# Out:
#                         DEPARTMENT  GENDER
# 0      Municipal Courts Department  Female
# 73           Human Resources Dept.  Female
# 96        City Controller's Office  Female
# 117               Legal Department  Female
# 146  Houston Information Tech Svcs  Female

# %% [markdown]
# # レシピ42 whereメソッドによるSeriesの保持

# %% [markdown]
# #### whereメソッドはSeriesとDataFrameのサイズを保持し、基準に合致してない値を欠損値にするか他のものに置き換える

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
fb_likes = movie['actor_1_facebook_likes'].dropna()
fb_likes.head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      40000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         27000.0
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# describeメソッドで分布をつかむ
fb_likes.describe(percentiles=[.1,.25, .5, .75, .9]).astype(int)
# Out:
# count      4909
# mean       6494
# std       15106
# min           0
# 10%         240
# 25%         607
# 50%         982
# 75%       11000
# 90%       18000
# max      640000
# Name: actor_1_facebook_likes, dtype: int32

# %%
# ヒストグラムにして分布を確認
fb_likes.hist()

# %%
# fb_likesの個数が2万より少ないかチェックする基準を作る
criteria_high = fb_likes < 20000
criteria_high.mean().round(2)
# Out:
# 0.91

# %%
# whereメソッドを使う、Falseは全て欠損値で置き換える
fb_likes.where(criteria_high).head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End          NaN
# Spectre                                       11000.0
# The Dark Knight Rises                             NaN
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# whereの第2パラメータotherで置換する値を制御できる
fb_likes.where(criteria_high, other=20000).head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      20000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         20000.0
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# fb_likesの最小個数300の下限設定基準を設ける
criteria_low = fb_likes > 300
fb_likes_cap = fb_likes.where(criteria_high, other=20000)\
                        .where(criteria_low, 300)
fb_likes_cap.head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      20000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         20000.0
# Star Wars: Episode VII - The Force Awakens      300.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# 元のSeriesの長さと変更したSeriesの長さは同じ
len(fb_likes), len(fb_likes_cap)
# Out:
# (4909, 4909)

# %%
# 修正Seriesのヒストグラムを作成する
fb_likes_cap.hist()

# %%
# whereで切り上げ切り下げをした代わりとなるclip,clip_lower,clip_upperがある
fb_likes_cap2 = fb_likes.clip(lower=300, upper=20000)
fb_likes_cap2.equals(fb_likes_cap)
# Out:
# True

# %% [markdown]
# # レシピ43 DataFrameの行のマスキング

# %% [markdown]
# #### maskメソッドはBoolean条件がTrueになるところを欠損値にする
# - このレシピでは映画データセットで2010年より後の映画にマスキングして欠損値のある行を全てフィルタリングする

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
c1 = movie['title_year'] >= 2010
c2 = movie['title_year'].isnull()
criteria = c1 | c2

# %%
# maskメソッドで2010年より後の映画の行の値を欠損値にする
movie.mask(criteria).head()
# Out:
#                                             color   director_name  \
# movie_title
# Avatar                                      Color   James Cameron
# Pirates of the Caribbean: At World's End    Color  Gore Verbinski
# Spectre                                       NaN             NaN
# The Dark Knight Rises                         NaN             NaN
# Star Wars: Episode VII - The Force Awakens    NaN             NaN
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                        NaN       NaN
# The Dark Knight Rises                                          NaN       NaN
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
# dropnaをチェイニングして全部が欠損値の行を取り除く
movie_mask = movie.mask(criteria).dropna(how='all')
movie_mask.head()
# Out:
#                                           color   director_name  \
# movie_title
# Avatar                                    Color   James Cameron
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# Spider-Man 3                              Color       Sam Raimi
# Harry Potter and the Half-Blood Prince    Color     David Yates
# Superman Returns                          Color    Bryan Singer
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spider-Man 3                                               392.0     156.0
# Harry Potter and the Half-Blood Prince                     375.0     153.0
# Superman Returns                                           434.0     169.0
#
#                                           director_facebook_likes  \
# movie_title
# ...

# %%
# maskとbooleanインデックス法が同じになるかチェックする
movie_boolean = movie[movie['title_year'] < 2010]
movie_mask.equals(movie_boolean)
# Out:
# False

# %%
# 同じ形かどうか確認する
movie_mask.shape == movie_boolean.shape
# Out:
# True

# %%
# equalsメソッドはカラム値が同じでもデータ型が異なるとFalseを返す。データ型を確認する
movie_mask.dtypes == movie_boolean.dtypes
# Out:
# color                         True
# director_name                 True
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                  True
# actor_1_facebook_likes        True
# gross                         True
# genres                        True
# actor_1_name                  True
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster          True
# plot_keywords                 True
# movie_imdb_link               True
# num_user_for_reviews          True
# language                      True
# country                       True
# content_rating                True
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                    True
# aspect_ratio                  True
# movie_facebook_likes         False
# ...

# %%
# maskとBooleanインデックス法との速度差を比較
# %timeit movie.mask(criteria).dropna(how="all")
# Out:
# 22.5 ms ± 270 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Booleanインデックス法の方が一桁速い
# %timeit movie[movie['title_year'] < 2010]
# Out:
# 820 µs ± 16.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # レシピ44 Boolean, 整数位置, ラベルによる選択

# %% [markdown]
# #### .ilocと.locで行とカラムをフィルタリングする

# %%
# 内容評価がGでIMDB点数が4より低い全映画にマッチングするBoolean_Seriesを作成
c1 = movie['content_rating'] == 'G'
c2 = movie['imdb_score'] < 4
criteria = c1 & c2

# %%
# .locで行をフィルタリングする
movie_loc = movie.loc[criteria]
movie_loc.head()
# Out:
#                                 color     director_name  \
# movie_title
# The True Story of Puss'N Boots  Color  Jérôme Deschamps
# Doogal                          Color    Dave Borthwick
# Thomas and the Magic Railroad   Color    Britt Allcroft
# Barney's Great Adventure        Color       Steve Gomer
# Justin Bieber: Never Say Never  Color        Jon M. Chu
#
#                                 num_critic_for_reviews  duration  \
# movie_title
# The True Story of Puss'N Boots                     4.0      80.0
# Doogal                                            31.0      77.0
# Thomas and the Magic Railroad                     47.0      85.0
# Barney's Great Adventure                          24.0      76.0
# Justin Bieber: Never Say Never                    84.0     115.0
#
#                                 director_facebook_likes  \
# movie_title
# The True Story of Puss'N Boots                      0.0
# Doogal                                              3.0
# ...

# %%
# インデックス演算子で直接作られたものと等しいか確認する
movie_loc.equals(movie[criteria])
# Out:
# True

# %%
# Booleanのndarrayならilocは使えるので、配列抽出にvalues属性をつかう
movie_iloc = movie.iloc[criteria.values]
movie_iloc.equals(movie_loc)
# Out:
# True

# %%
# カラム選択にBooleanインデックス法を使う
criteria_col = movie.dtypes == np.int64
criteria_col.head()
# Out:
# color                      False
# director_name              False
# num_critic_for_reviews     False
# duration                   False
# director_facebook_likes    False
# dtype: bool

# %%
movie.loc[:, criteria_col].head()
# Out:
#                                             num_voted_users  \
# movie_title
# Avatar                                               886204
# Pirates of the Caribbean: At World's End             471220
# Spectre                                              275868
# The Dark Knight Rises                               1144337
# Star Wars: Episode VII - The Force Awakens                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# ...

# %%
# 上記と同じ結果をilocで得る為にはndarrayを用いる必要がある
movie.iloc[:, criteria_col.values].head()
# Out:
#                                             num_voted_users  \
# movie_title
# Avatar                                               886204
# Pirates of the Caribbean: At World's End             471220
# Spectre                                              275868
# The Dark Knight Rises                               1144337
# Star Wars: Episode VII - The Force Awakens                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# ...

# %%
# Booleanフィルタを行選択で使う場合は、カラム選択は別に必要
cols = ['content_rating', 'imdb_score', 'title_year', 'gross']
movie.loc[criteria, cols].sort_values('imdb_score')
# Out:
#                                content_rating  imdb_score  title_year  \
# movie_title
# Justin Bieber: Never Say Never              G         1.6      2011.0
# Sunday School Musical                       G         2.5      2008.0
# Doogal                                      G         2.8      2006.0
# Barney's Great Adventure                    G         2.8      1998.0
# The True Story of Puss'N Boots              G         2.9      2009.0
# Thomas and the Magic Railroad               G         3.6      2000.0
#
#                                      gross
# movie_title
# Justin Bieber: Never Say Never  73000942.0
# Sunday School Musical                  NaN
# Doogal                           7382993.0
# Barney's Great Adventure        11144518.0
# The True Story of Puss'N Boots         NaN
# Thomas and the Magic Railroad   15911333.0

# %%
# 上記と同じことを.ilocでやる場合、全カラムの整数位置を取得する必要がある
col_index = [movie.columns.get_loc(col) for col in cols]
col_index
# Out:
# [20, 24, 22, 8]

# %%
movie.iloc[criteria.values, col_index]
# Out:
#                                content_rating  imdb_score  title_year  \
# movie_title
# The True Story of Puss'N Boots              G         2.9      2009.0
# Doogal                                      G         2.8      2006.0
# Thomas and the Magic Railroad               G         3.6      2000.0
# Barney's Great Adventure                    G         2.8      1998.0
# Justin Bieber: Never Say Never              G         1.6      2011.0
# Sunday School Musical                       G         2.5      2008.0
#
#                                      gross
# movie_title
# The True Story of Puss'N Boots         NaN
# Doogal                           7382993.0
# Thomas and the Magic Railroad   15911333.0
# Barney's Great Adventure        11144518.0
# Justin Bieber: Never Say Never  73000942.0
# Sunday School Musical                  NaN
