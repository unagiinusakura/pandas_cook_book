# %% [markdown]
# # Chapter 4: データから部分抽出
#
# ## レシピ
# * [Seriesデータの選択](#レシピ26-Seriesデータの選択)
# * [DataFrameの行の選択](#レシピ27-DataFrameの行の選択)
# * [DataFrameの行とカラムの同時選択](#レシピ28-DataFrameの行とカラムの同時選択)
# * [整数とラベルの両方でデータ選択](#レシピ29-整数とラベルの両方でデータ選択)
# * [スカラー選択の高速化](#レシピ30-スカラー選択の高速化)
# * [行の手軽なスライシング](#レシピ31-行の手軽なスライシング)
# * [文字順にスライシング](#レシピ32-文字順にスライシング)

# %%
import pandas as pd
import numpy as np
from IPython.display import display
pd.options.display.max_columns = 50

# %% [markdown]
# # レシピ26 Seriesデータの選択

# %%
# 大学データセットを校名をインデックスとして読み込む
college = pd.read_csv('data/college.csv', index_col='INSTNM')
city = college['CITY']
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
# ilocで抽出
city.iloc[3]
# Out:
# 'Huntsville'

# %%
# ilocにリストを渡し、複数の整数位置を選択
city.iloc[[10,20,30]]
# Out:
# INSTNM
# Birmingham Southern College                            Birmingham
# George C Wallace State Community College-Hanceville    Hanceville
# Judson College                                             Marion
# Name: CITY, dtype: object

# %%
# スライス表記を用いて、等間隔にデータを選ぶ
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
# indexラベルで抽出するloc
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %%
# 複数の異なるラベルを選択するにはリスト
np.random.seed(1)
labels =list(np.random.choice(city.index,4))
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
city.loc[labels]
# Out:
# INSTNM
# Northwest HVAC/R Training Center                Spokane
# California State University-Dominguez Hills      Carson
# Lower Columbia College                         Longview
# Southwest Acupuncture College-Boulder           Boulder
# Name: CITY, dtype: object

# %%
# データを等間隔で選ぶにはスライス
city.loc['Alabama State University': 'Reid State Technical College':10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# # レシピ27 DataFrameの行の選択

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                      0.0   4206.0      0.0333
# University of Alabama at Birmingham           0.0  11383.0      0.5922
# Amridge University                            1.0    291.0      0.2990
# University of Alabama in Huntsville           0.0   5451.0      0.6988
# Alabama State University                      0.0   4811.0      0.0158
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                 0.9353     0.0055      0.0019
# University of Alabama at Birmingham      0.2600     0.0283      0.0518
# Amridge University                       0.4192     0.0069      0.0034
# University of Alabama in Huntsville      0.1255     0.0382      0.0376
# Alabama State University                 0.9208     0.0121      0.0019
#
#                                      UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                0.0024     0.0019     0.0000
# University of Alabama at Birmingham     0.0022     0.0007     0.0368
# Amridge University                      0.0000     0.0000     0.0000
# University of Alabama in Huntsville     0.0143     0.0002     0.0172
# Alabama State University                0.0010     0.0006     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656         1
# University of Alabama at Birmingham    0.0179     0.0100    0.2607         1
# Amridge University                     0.0000     0.2715    0.4536         1
# University of Alabama in Huntsville    0.0332     0.0350    0.2146         1
# Alabama State University               0.0243     0.0137    0.0892         1
#
#                                      PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University              0.7356    0.8284   0.1049
# University of Alabama at Birmingham   0.3460    0.5214   0.2422
# Amridge University                    0.6801    0.7795   0.8540
# University of Alabama in Huntsville   0.3072    0.4596   0.2640
# Alabama State University              0.7347    0.7554   0.1270
#
#                                     MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                      30300              33888
# University of Alabama at Birmingham           39700            21941.5
# Amridge University                            40100              23370
# University of Alabama in Huntsville           45500              24097
# Alabama State University                      26600            33118.5

# %%
# ilocに整数を渡し、その位置の行全体を選ぶ
college.iloc[60]
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
# locにindexラベルを渡す
college.loc['University of Alaska Anchorage']
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
# 複数行を選ぶにはilocに整数のリストを渡す
college.iloc[[60, 99, 3]]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0      0.5747
# International Academy of Hair Design           0.0    188.0      0.2713
# University of Alabama in Huntsville            0.0   5451.0      0.6988
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# University of Alaska Anchorage            0.0358     0.0761      0.0778
# International Academy of Hair Design      0.2500     0.3670      0.0160
# University of Alabama in Huntsville       0.1255     0.0382      0.0376
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# University of Alaska Anchorage           0.0653     0.0086     0.0980
# International Academy of Hair Design     0.0160     0.0000     0.0160
# University of Alabama in Huntsville      0.0143     0.0002     0.0172
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# University of Alaska Anchorage          0.0181     0.0457    0.4539         1
# International Academy of Hair Design    0.0000     0.0638    0.0000         0
# University of Alabama in Huntsville     0.0332     0.0350    0.2146         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# University of Alaska Anchorage         0.2385    0.2647   0.4386
# International Academy of Hair Design   0.7185    0.7346   0.3905
# University of Alabama in Huntsville    0.3072    0.4596   0.2640
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# University of Alaska Anchorage                 42500            19449.5
# International Academy of Hair Design           22200              10556
# University of Alabama in Huntsville            45500              24097

# %%
# locを用いて複数行を選択する
labels = ['University of Alaska Anchorage',
          'International Academy of Hair Design',
          'University of Alabama in Huntsville']
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0      0.5747
# International Academy of Hair Design           0.0    188.0      0.2713
# University of Alabama in Huntsville            0.0   5451.0      0.6988
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# University of Alaska Anchorage            0.0358     0.0761      0.0778
# International Academy of Hair Design      0.2500     0.3670      0.0160
# University of Alabama in Huntsville       0.1255     0.0382      0.0376
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# University of Alaska Anchorage           0.0653     0.0086     0.0980
# International Academy of Hair Design     0.0160     0.0000     0.0160
# University of Alabama in Huntsville      0.0143     0.0002     0.0172
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# University of Alaska Anchorage          0.0181     0.0457    0.4539         1
# International Academy of Hair Design    0.0000     0.0638    0.0000         0
# University of Alabama in Huntsville     0.0332     0.0350    0.2146         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# University of Alaska Anchorage         0.2385    0.2647   0.4386
# International Academy of Hair Design   0.7185    0.7346   0.3905
# University of Alabama in Huntsville    0.3072    0.4596   0.2640
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# University of Alaska Anchorage                 42500            19449.5
# International Academy of Hair Design           22200              10556
# University of Alabama in Huntsville            45500              24097

# %%
# index_listは切り貼りしなくてもDataFrameから直接取り出せる
college.iloc[[60, 99, 3]].index.tolist()
# Out:
# ['University of Alaska Anchorage',
#  'International Academy of Hair Design',
#  'University of Alabama in Huntsville']

# %%
# ilocでスライス表記する
college.iloc[99:102]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# International Academy of Hair Design           0.0    188.0      0.2713
# GateWay Community College                      0.0   5211.0      0.3585
# Mesa Community College                         0.0  19055.0      0.5002
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# International Academy of Hair Design      0.2500     0.3670      0.0160
# GateWay Community College                 0.1201     0.3389      0.0355
# Mesa Community College                    0.0661     0.2354      0.0390
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# International Academy of Hair Design     0.0160     0.0000     0.0160
# GateWay Community College                0.0451     0.0029     0.0127
# Mesa Community College                   0.0403     0.0046     0.0205
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# International Academy of Hair Design    0.0000     0.0638    0.0000         0
# GateWay Community College               0.0161     0.0702    0.7465         1
# Mesa Community College                  0.0257     0.0682    0.6457         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# International Academy of Hair Design   0.7185    0.7346   0.3905
# GateWay Community College              0.3270    0.2189   0.5832
# Mesa Community College                 0.3423    0.2207   0.4010
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# International Academy of Hair Design           22200              10556
# GateWay Community College                      29800               7283
# Mesa Community College                         35200               8000

# %%
# locでスライス表記
start = 'International Academy of Hair Design'
stop = 'Mesa Community College'
college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# International Academy of Hair Design           0.0    188.0      0.2713
# GateWay Community College                      0.0   5211.0      0.3585
# Mesa Community College                         0.0  19055.0      0.5002
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# International Academy of Hair Design      0.2500     0.3670      0.0160
# GateWay Community College                 0.1201     0.3389      0.0355
# Mesa Community College                    0.0661     0.2354      0.0390
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# International Academy of Hair Design     0.0160     0.0000     0.0160
# GateWay Community College                0.0451     0.0029     0.0127
# Mesa Community College                   0.0403     0.0046     0.0205
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# International Academy of Hair Design    0.0000     0.0638    0.0000         0
# GateWay Community College               0.0161     0.0702    0.7465         1
# Mesa Community College                  0.0257     0.0682    0.6457         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# International Academy of Hair Design   0.7185    0.7346   0.3905
# GateWay Community College              0.3270    0.2189   0.5832
# Mesa Community College                 0.3423    0.2207   0.4010
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# International Academy of Hair Design           22200              10556
# GateWay Community College                      29800               7283
# Mesa Community College                         35200               8000

# %% [markdown]
# # レシピ28 DataFrameの行とカラムの同時選択

# %% [markdown]
# ### 行とカラムを選択する原始的な形式は次のようなコードになる
# - df.iloc[rows, columns]
# - df.loc[rows, columns]

# %%
# スライス表記で最初の3行と最初の4カラムを選ぶ
college.iloc[:3,:4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
# 異なるカラム2つの全行を選ぶ
college.iloc[:,[4,6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
college.loc[:,['WOMENONLY', 'SATVRMID']].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
# 共通部分のない行の集合と列の集合を選ぶ
college.iloc[[100,200],[7,15]]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
rows = ['GateWay Community College',
        'American Baptist Seminary of the West']
columns = ['SATMTMID', 'UGDS_NHPI']
college.loc[rows, columns]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
# 単一スカラー値を選ぶ
college.iloc[5,-4]
# Out:
# 0.401

# %%
college.loc['The University of Alabama', 'PCTFLOAN']
# Out:
# 0.401

# %%
# 行をスライスして１つのカラムを選ぶ
college.iloc[90:80:-2,5]
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
start = 'Empire Beauty School-Flagstaff'
stop = 'Arizona State University-Tempe'
college.loc[start:stop:-2, 'RELAFFIL']
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %% [markdown]
# # レシピ29 整数とラベルの両方でデータ選択

# %% [markdown]
# #### カラムの整数位置をどのようにして見つけるかとilocを使って選択を完了

# %%
# Indexメソッドget_locを使って必要なカラムの整数位置を見つける
col_start = college.columns.get_loc('UGDS_WHITE')
col_end = college.columns.get_loc('UGDS_UNKN') + 1
col_start, col_end
# Out:
# (10, 19)

# %%
# ilocで整数位置を使い、col_startとcol_endを使ってカラムを選択する
college.iloc[:5, col_start:col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138
# University of Alabama at Birmingham     0.0368    0.0179     0.0100
# Amridge University                      0.0000    0.0000     0.2715
# University of Alabama in Huntsville     0.0172    0.0332     0.0350
# Alabama State University                0.0098    0.0243     0.0137

# %%
# locでも同様な事が出来る
row_start = college.index[10]
row_end = college.index[15]
college.loc[row_start:row_end, 'UGDS_WHITE': 'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# Enterprise State Community College            0.0202     0.0081     0.0029
# James H Faulkner State Community College      0.0084     0.0177     0.0014
#
#                                           UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Birmingham Southern College                  0.0051    0.0000     0.0051
# Chattahoochee Valley Community College       0.0151    0.0000     0.0139
# Concordia College Alabama                    0.0031    0.0466     0.0000
# South University-Montgomery                  0.0000    0.0019     0.0326
# Enterprise State Community College           0.0254    0.0012     0.0069
# James H Faulkner State Community College     0.0152    0.0007     0.0009

# %% [markdown]
# # レシピ30 スカラー選択の高速化

# %% [markdown]
# #### スカラー値を高速に行うには、.iat及び.atを使う

# %%
# locで校名とカラム名を渡して、スカラー値を選ぶ
cn = 'Texas A & M University-College Station'
college.loc[cn, 'UGDS_WHITE']
# Out:
# 0.6609999999999999

# %%
# 同じ結果を.atで得る
college.at[cn, 'UGDS_WHITE']
# Out:
# 0.6609999999999999

# %%
# マジックコマンド%timeitを使って速度の違いを得る
# %timeit college.loc[cn, 'UGDS_WHITE']
# Out:
# 5.72 µs ± 344 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit college.at[cn, 'UGDS_WHITE']
# Out:
# 3.59 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# ilocとiatの速度の違いを測る
row_num = college.index.get_loc(cn)
col_num = college.columns.get_loc('UGDS_WHITE')
row_num, col_num
# Out:
# (3765, 10)

# %%
# %timeit college.iloc[row_num, col_num]
# Out:
# 6.29 µs ± 298 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit college.iat[row_num, col_num]
# Out:
# 3.75 µs ± 35.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# # レシピ31 行の手軽なスライシング

# %% [markdown]
# #### SeriesとDataFrame両方のインデックス演算子にスライスオブジェクトを渡す

# %%
# インデックス10から20まで2行おきに行を選択する
college[10:20:2]
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Birmingham Southern College            Birmingham     AL   0.0      0.0
# Concordia College Alabama                   Selma     AL   1.0      0.0
# Enterprise State Community College     Enterprise     AL   0.0      0.0
# Faulkner University                    Montgomery     AL   0.0      0.0
# New Beginning College of Cosmetology  Albertville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Birmingham Southern College                 0.0         1     560.0     560.0
# Concordia College Alabama                   0.0         1     420.0     400.0
# Enterprise State Community College          0.0         0       NaN       NaN
# Faulkner University                         0.0         1       NaN       NaN
# New Beginning College of Cosmetology        0.0         0       NaN       NaN
#
#                                       DISTANCEONLY    UGDS  UGDS_WHITE  \
# INSTNM
# Birmingham Southern College                    0.0  1180.0      0.7983
# Concordia College Alabama                      0.0   322.0      0.0280
# Enterprise State Community College             0.0  1729.0      0.6408
# Faulkner University                            0.0  2367.0      0.3874
# New Beginning College of Cosmetology           0.0   115.0      0.8957
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Birmingham Southern College               0.1102     0.0195      0.0517
# Concordia College Alabama                 0.8758     0.0373      0.0093
# Enterprise State Community College        0.2435     0.0509      0.0202
# Faulkner University                       0.5137     0.0258      0.0042
# New Beginning College of Cosmetology      0.0348     0.0696      0.0000
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Birmingham Southern College              0.0102     0.0000     0.0051
# Concordia College Alabama                0.0000     0.0000     0.0031
# Enterprise State Community College       0.0081     0.0029     0.0254
# Faulkner University                      0.0063     0.0013     0.0173
# New Beginning College of Cosmetology     0.0000     0.0000     0.0000
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Birmingham Southern College             0.0000     0.0051    0.0017         1
# Concordia College Alabama               0.0466     0.0000    0.1056         1
# Enterprise State Community College      0.0012     0.0069    0.3823         1
# Faulkner University                     0.0182     0.0258    0.2302         1
# New Beginning College of Cosmetology    0.0000     0.0000    0.0783         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Birmingham Southern College            0.1920    0.4809   0.0152
# Concordia College Alabama              0.8667    0.9333   0.2367
# Enterprise State Community College     0.4895    0.2263   0.3399
# Faulkner University                    0.5812    0.7253   0.4589
# New Beginning College of Cosmetology   0.8224    0.8553   0.3933
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# Birmingham Southern College                    44200              27000
# Concordia College Alabama                      19900  PrivacySuppressed
# Enterprise State Community College             24600               8273
# Faulkner University                            37200              22000
# New Beginning College of Cosmetology             NaN               5500

# %%
# 同じスライシングをSeriesでも行う
city = college['CITY']
city[10:20:2]
# Out:
# INSTNM
# Birmingham Southern College              Birmingham
# Concordia College Alabama                     Selma
# Enterprise State Community College       Enterprise
# Faulkner University                      Montgomery
# New Beginning College of Cosmetology    Albertville
# Name: CITY, dtype: object

# %%
# SeriesもDataFrameもインデックス演算子にラベルでもスライシングできる
start = 'Mesa Community College'
stop = 'Spokane Community College'
college[start:stop:1500]
# Out:
#                                                 CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Mesa Community College                          Mesa     AZ   0.0      0.0
# Hair Academy Inc-New Carrollton       New Carrollton     MD   0.0      0.0
# National College of Natural Medicine        Portland     OR   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Mesa Community College                      0.0         0       NaN       NaN
# Hair Academy Inc-New Carrollton             0.0         0       NaN       NaN
# National College of Natural Medicine        0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  UGDS_WHITE  \
# INSTNM
# Mesa Community College                         0.0  19055.0      0.5002
# Hair Academy Inc-New Carrollton                0.0    504.0      0.0000
# National College of Natural Medicine           0.0      NaN         NaN
#
#                                       UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Mesa Community College                    0.0661     0.2354       0.039
# Hair Academy Inc-New Carrollton           0.9940     0.0040       0.000
# National College of Natural Medicine         NaN        NaN         NaN
#
#                                       UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Mesa Community College                   0.0403     0.0046     0.0205
# Hair Academy Inc-New Carrollton          0.0020     0.0000     0.0000
# National College of Natural Medicine        NaN        NaN        NaN
#
#                                       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Mesa Community College                  0.0257     0.0682    0.6457         1
# Hair Academy Inc-New Carrollton         0.0000     0.0000    0.4683         1
# National College of Natural Medicine       NaN        NaN       NaN         1
#
#                                       PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Mesa Community College                 0.3423    0.2207   0.4010
# Hair Academy Inc-New Carrollton        0.9756    1.0000   0.5882
# National College of Natural Medicine      NaN       NaN      NaN
#
#                                      MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# Mesa Community College                         35200               8000
# Hair Academy Inc-New Carrollton                15200               9666
# National College of Natural Medicine             NaN  PrivacySuppressed

# %%
# Seriesに同じスライシングをする
city[start:stop:1500]
# Out:
# INSTNM
# Mesa Community College                            Mesa
# Hair Academy Inc-New Carrollton         New Carrollton
# National College of Natural Medicine          Portland
# Name: CITY, dtype: object

# %% [markdown]
# # レシピ32 文字順にスライシング

# %% [markdown]
# #### インデックスでソートし、locでスライス表記を用いて２つの文字列の間の全ての行を選ぶ

# %%
# 校名が文字列順でSpとSuの間の全大学を選ぼうとする
college.loc['Sp':'Su']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5166             try:
# -> 5167                 return self._searchsorted_monotonic(label, side)
#    5168             except ValueError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    5127
# -> 5128         raise ValueError("index must be monotonic increasing or decreasing")
#    5129
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-11ae10e4a997> in <module>
#       1 # 校名が文字列順でSpとSuの間の全大学を選ぼうとする
# ----> 2 college.loc['Sp':'Su']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1452         labels = obj._get_axis(axis)
#    1453         indexer = labels.slice_indexer(
# -> 1454             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1455         )
#    1456
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5032         slice(1, 3)
#    5033         """
# -> 5034         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5035
#    5036         # return a slice
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5246         start_slice = None
#    5247         if start is not None:
# -> 5248             start_slice = self.get_slice_bound(start, "left", kind)
#    5249         if start_slice is None:
#    5250             start_slice = 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5168             except ValueError:
#    5169                 # raise the original KeyError
# -> 5170                 raise err
#    5171
#    5172         if isinstance(slc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5162         # we need to look up the label
#    5163         try:
# -> 5164             slc = self.get_loc(label)
#    5165         except KeyError as err:
#    5166             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sp'

# %%
# インデックスをソートする
college = college.sort_index()
college
# Out:
#                                                               CITY STABBR  \
# INSTNM
# A & W Healthcare Educators                             New Orleans     LA
# A T Still University of Health Sciences                 Kirksville     MO
# ABC Beauty Academy                                         Garland     TX
# ABC Beauty College Inc                                 Arkadelphia     AR
# AI Miami International University of Art and De...           Miami     FL
# ...                                                            ...    ...
# Yukon Beauty College Inc                                     Yukon     OK
# Z Hair Academy                                            Lawrence     KS
# Zane State College                                      Zanesville     OH
# duCret School of Arts                                   Plainfield     NJ
# eClips School of Cosmetology and Barbering          Cape Girardeau     MO
#
#                                                     HBCU  MENONLY  WOMENONLY  \
# INSTNM
# A & W Healthcare Educators                           0.0      0.0        0.0
# A T Still University of Health Sciences              0.0      0.0        0.0
# ABC Beauty Academy                                   0.0      0.0        0.0
# ABC Beauty College Inc                               0.0      0.0        0.0
# AI Miami International University of Art and De...   0.0      0.0        0.0
# ...                                                  ...      ...        ...
# Yukon Beauty College Inc                             0.0      0.0        0.0
# Z Hair Academy                                       0.0      0.0        0.0
# Zane State College                                   0.0      0.0        0.0
# duCret School of Arts                                0.0      0.0        0.0
# eClips School of Cosmetology and Barbering           0.0      0.0        0.0
#
#                                                     RELAFFIL  SATVRMID  \
# INSTNM
# A & W Healthcare Educators                                 0       NaN
# A T Still University of Health Sciences                    0       NaN
# ABC Beauty Academy                                         0       NaN
# ABC Beauty College Inc                                     0       NaN
# AI Miami International University of Art and De...         0       NaN
# ...                                                      ...       ...
# Yukon Beauty College Inc                                   0       NaN
# Z Hair Academy                                             0       NaN
# Zane State College                                         0       NaN
# duCret School of Arts                                      0       NaN
# eClips School of Cosmetology and Barbering                 0       NaN
#
#                                                     SATMTMID  DISTANCEONLY  \
# INSTNM
# A & W Healthcare Educators                               NaN           0.0
# A T Still University of Health Sciences                  NaN           0.0
# ABC Beauty Academy                                       NaN           0.0
# ABC Beauty College Inc                                   NaN           0.0
# AI Miami International University of Art and De...       NaN           0.0
# ...                                                      ...           ...
# Yukon Beauty College Inc                                 NaN           0.0
# Z Hair Academy                                           NaN           0.0
# Zane State College                                       NaN           0.0
# duCret School of Arts                                    NaN           0.0
# eClips School of Cosmetology and Barbering               NaN           0.0
#
#                                                       UGDS  UGDS_WHITE  \
# INSTNM
# A & W Healthcare Educators                            40.0      0.0000
# A T Still University of Health Sciences                NaN         NaN
# ABC Beauty Academy                                    30.0      0.0000
# ABC Beauty College Inc                                38.0      0.2895
# AI Miami International University of Art and De...  2778.0      0.0324
# ...                                                    ...         ...
# Yukon Beauty College Inc                              25.0      0.8000
# Z Hair Academy                                        95.0      0.9368
# Zane State College                                  2063.0      0.6995
# duCret School of Arts                                 41.0      0.4634
# eClips School of Cosmetology and Barbering            83.0      0.1446
#
#                                                     UGDS_BLACK  UGDS_HISP  \
# INSTNM
# A & W Healthcare Educators                              0.9750     0.0250
# A T Still University of Health Sciences                    NaN        NaN
# ABC Beauty Academy                                      0.0333     0.0333
# ABC Beauty College Inc                                  0.6579     0.0526
# AI Miami International University of Art and De...      0.0198     0.4773
# ...                                                        ...        ...
# Yukon Beauty College Inc                                0.0400     0.0000
# Z Hair Academy                                          0.0000     0.0211
# Zane State College                                      0.0296     0.0029
# duCret School of Arts                                   0.1951     0.1463
# eClips School of Cosmetology and Barbering              0.8554     0.0000
#
#                                                     UGDS_ASIAN  UGDS_AIAN  \
# INSTNM
# A & W Healthcare Educators                              0.0000     0.0000
# A T Still University of Health Sciences                    NaN        NaN
# ABC Beauty Academy                                      0.9333     0.0000
# ABC Beauty College Inc                                  0.0000     0.0000
# AI Miami International University of Art and De...      0.0018     0.0000
# ...                                                        ...        ...
# Yukon Beauty College Inc                                0.0000     0.1200
# Z Hair Academy                                          0.0000     0.0000
# Zane State College                                      0.0029     0.0029
# duCret School of Arts                                   0.0732     0.0000
# eClips School of Cosmetology and Barbering              0.0000     0.0000
#
#                                                     UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# A & W Healthcare Educators                             0.0000     0.0000
# A T Still University of Health Sciences                   NaN        NaN
# ABC Beauty Academy                                     0.0000     0.0000
# ABC Beauty College Inc                                 0.0000     0.0000
# AI Miami International University of Art and De...     0.0000     0.0018
# ...                                                       ...        ...
# Yukon Beauty College Inc                               0.0400     0.0000
# Z Hair Academy                                         0.0105     0.0211
# Zane State College                                     0.0005     0.0218
# duCret School of Arts                                  0.0000     0.0976
# eClips School of Cosmetology and Barbering             0.0000     0.0000
#
#                                                     UGDS_NRA  UGDS_UNKN  \
# INSTNM
# A & W Healthcare Educators                            0.0000     0.0000
# A T Still University of Health Sciences                  NaN        NaN
# ABC Beauty Academy                                    0.0000     0.0000
# ABC Beauty College Inc                                0.0000     0.0000
# AI Miami International University of Art and De...    0.0025     0.4644
# ...                                                      ...        ...
# Yukon Beauty College Inc                              0.0000     0.0000
# Z Hair Academy                                        0.0000     0.0105
# Zane State College                                    0.0000     0.2399
# duCret School of Arts                                 0.0000     0.0244
# eClips School of Cosmetology and Barbering            0.0000     0.0000
#
#                                                     PPTUG_EF  CURROPER  \
# INSTNM
# A & W Healthcare Educators                            0.1250         1
# A T Still University of Health Sciences                  NaN         1
# ABC Beauty Academy                                    0.0000         0
# ABC Beauty College Inc                                0.2105         1
# AI Miami International University of Art and De...    0.2185         1
# ...                                                      ...       ...
# Yukon Beauty College Inc                              0.0000         1
# Z Hair Academy                                        0.0000         1
# Zane State College                                    0.5730         1
# duCret School of Arts                                 0.4146         1
# eClips School of Cosmetology and Barbering            0.0000         1
#
#                                                     PCTPELL  PCTFLOAN  \
# INSTNM
# A & W Healthcare Educators                           0.7018    0.8596
# A T Still University of Health Sciences                 NaN       NaN
# ABC Beauty Academy                                   0.7857    0.0000
# ABC Beauty College Inc                               0.9815    1.0000
# AI Miami International University of Art and De...   0.5507    0.6966
# ...                                                     ...       ...
# Yukon Beauty College Inc                             0.9259    0.8148
# Z Hair Academy                                       0.7286    0.6571
# Zane State College                                   0.3645    0.3434
# duCret School of Arts                                0.4375    0.5000
# eClips School of Cosmetology and Barbering           0.9496    0.9832
#
#                                                     UG25ABV  \
# INSTNM
# A & W Healthcare Educators                           0.6667
# A T Still University of Health Sciences                 NaN
# ABC Beauty Academy                                   0.8286
# ABC Beauty College Inc                               0.4688
# AI Miami International University of Art and De...   0.3262
# ...                                                     ...
# Yukon Beauty College Inc                             0.4706
# Z Hair Academy                                       0.1525
# Zane State College                                   0.3185
# duCret School of Arts                                0.1250
# eClips School of Cosmetology and Barbering           0.3772
#
#                                                       MD_EARN_WNE_P10  \
# INSTNM
# A & W Healthcare Educators                                        NaN
# A T Still University of Health Sciences                        219800
# ABC Beauty Academy                                                NaN
# ABC Beauty College Inc                              PrivacySuppressed
# AI Miami International University of Art and De...              29900
# ...                                                               ...
# Yukon Beauty College Inc                            PrivacySuppressed
# Z Hair Academy                                                    NaN
# Zane State College                                              23800
# duCret School of Arts                               PrivacySuppressed
# eClips School of Cosmetology and Barbering          PrivacySuppressed
#
#                                                    GRAD_DEBT_MDN_SUPP
# INSTNM
# A & W Healthcare Educators                                    19022.5
# A T Still University of Health Sciences             PrivacySuppressed
# ABC Beauty Academy                                  PrivacySuppressed
# ABC Beauty College Inc                                          16500
# AI Miami International University of Art and De...              31000
# ...                                                               ...
# Yukon Beauty College Inc                            PrivacySuppressed
# Z Hair Academy                                                  10500
# Zane State College                                            13960.5
# duCret School of Arts                               PrivacySuppressed
# eClips School of Cosmetology and Barbering                       9500
#
# [7535 rows x 26 columns]

# %%
# インデックスが文字順にソートされている場合、スライスを渡す事ができる
college.loc['Sp':'Su']
# Out:
#                                                   CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Spa Tech Institute-Ipswich                     Ipswich     MA   0.0      0.0
# Spa Tech Institute-Plymouth                   Plymouth     MA   0.0      0.0
# Spa Tech Institute-Westboro                   Westboro     MA   0.0      0.0
# Spa Tech Institute-Westbrook                 Westbrook     ME   0.0      0.0
# Spalding University                         Louisville     KY   0.0      0.0
# ...                                                ...    ...   ...      ...
# Studio Academy of Beauty                      Chandler     AZ   0.0      0.0
# Studio Jewelers                               New York     NY   0.0      0.0
# Stylemaster College of Hair Design            Longview     WA   0.0      0.0
# Styles and Profiles Beauty College              Selmer     TN   0.0      0.0
# Styletrends Barber and Hairstyling Academy   Rock Hill     SC   0.0      0.0
#
#                                             WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Spa Tech Institute-Ipswich                        0.0         0       NaN
# Spa Tech Institute-Plymouth                       0.0         0       NaN
# Spa Tech Institute-Westboro                       0.0         0       NaN
# Spa Tech Institute-Westbrook                      0.0         0       NaN
# Spalding University                               0.0         1     490.0
# ...                                               ...       ...       ...
# Studio Academy of Beauty                          0.0         0       NaN
# Studio Jewelers                                   0.0         0       NaN
# Stylemaster College of Hair Design                0.0         0       NaN
# Styles and Profiles Beauty College                0.0         0       NaN
# Styletrends Barber and Hairstyling Academy        0.0         0       NaN
#
#                                             SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# Spa Tech Institute-Ipswich                       NaN           0.0    37.0
# Spa Tech Institute-Plymouth                      NaN           0.0   153.0
# Spa Tech Institute-Westboro                      NaN           0.0    90.0
# Spa Tech Institute-Westbrook                     NaN           0.0   240.0
# Spalding University                            440.0           0.0  1227.0
# ...                                              ...           ...     ...
# Studio Academy of Beauty                         NaN           0.0   332.0
# Studio Jewelers                                  NaN           0.0    55.0
# Stylemaster College of Hair Design               NaN           0.0    77.0
# Styles and Profiles Beauty College               NaN           0.0    31.0
# Styletrends Barber and Hairstyling Academy       NaN           0.0    45.0
#
#                                             UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Spa Tech Institute-Ipswich                      0.9459      0.0000     0.0000
# Spa Tech Institute-Plymouth                     0.7124      0.0131     0.0196
# Spa Tech Institute-Westboro                     0.8222      0.0333     0.1000
# Spa Tech Institute-Westbrook                    0.9417      0.0333     0.0042
# Spalding University                             0.6650      0.2127     0.0416
# ...                                                ...         ...        ...
# Studio Academy of Beauty                        0.4669      0.1145     0.3283
# Studio Jewelers                                 0.2545      0.1091     0.2727
# Stylemaster College of Hair Design              0.9481      0.0130     0.0260
# Styles and Profiles Beauty College              0.8710      0.1290     0.0000
# Styletrends Barber and Hairstyling Academy      0.0000      1.0000     0.0000
#
#                                             UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Spa Tech Institute-Ipswich                      0.0000     0.0000     0.0000
# Spa Tech Institute-Plymouth                     0.0065     0.0000     0.0000
# Spa Tech Institute-Westboro                     0.0222     0.0000     0.0000
# Spa Tech Institute-Westbrook                    0.0167     0.0000     0.0000
# Spalding University                             0.0114     0.0024     0.0024
# ...                                                ...        ...        ...
# Studio Academy of Beauty                        0.0090     0.0301     0.0030
# Studio Jewelers                                 0.3273     0.0000     0.0000
# Stylemaster College of Hair Design              0.0000     0.0000     0.0000
# Styles and Profiles Beauty College              0.0000     0.0000     0.0000
# Styletrends Barber and Hairstyling Academy      0.0000     0.0000     0.0000
#
#                                             UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Spa Tech Institute-Ipswich                     0.0000    0.0000     0.0541
# Spa Tech Institute-Plymouth                    0.0000    0.0000     0.2484
# Spa Tech Institute-Westboro                    0.0000    0.0000     0.0222
# Spa Tech Institute-Westbrook                   0.0000    0.0000     0.0042
# Spalding University                            0.0302    0.0016     0.0326
# ...                                               ...       ...        ...
# Studio Academy of Beauty                       0.0392    0.0000     0.0090
# Studio Jewelers                                0.0000    0.0364     0.0000
# Stylemaster College of Hair Design             0.0130    0.0000     0.0000
# Styles and Profiles Beauty College             0.0000    0.0000     0.0000
# Styletrends Barber and Hairstyling Academy     0.0000    0.0000     0.0000
#
#                                             PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Spa Tech Institute-Ipswich                    0.4054         1   0.2656
# Spa Tech Institute-Plymouth                   0.3399         1   0.3716
# Spa Tech Institute-Westboro                   0.5778         1   0.3409
# Spa Tech Institute-Westbrook                  0.2542         1   0.4350
# Spalding University                           0.2502         1   0.4442
# ...                                              ...       ...      ...
# Studio Academy of Beauty                      0.0000         1   0.5855
# Studio Jewelers                               0.6000         1   0.0451
# Stylemaster College of Hair Design            0.0000         1   0.8036
# Styles and Profiles Beauty College            0.0000         1   0.8182
# Styletrends Barber and Hairstyling Academy    0.5556         0   1.0000
#
#                                             PCTFLOAN  UG25ABV  \
# INSTNM
# Spa Tech Institute-Ipswich                    0.3906   0.7907
# Spa Tech Institute-Plymouth                   0.4266   0.6250
# Spa Tech Institute-Westboro                   0.4545   0.6882
# Spa Tech Institute-Westbrook                  0.5093   0.5224
# Spalding University                           0.6725   0.3764
# ...                                              ...      ...
# Studio Academy of Beauty                      0.6218   0.5675
# Studio Jewelers                               0.0902   0.8525
# Stylemaster College of Hair Design            0.7024   0.4510
# Styles and Profiles Beauty College            0.7955   0.2400
# Styletrends Barber and Hairstyling Academy    1.0000   0.3529
#
#                                               MD_EARN_WNE_P10  \
# INSTNM
# Spa Tech Institute-Ipswich                              21500
# Spa Tech Institute-Plymouth                             21500
# Spa Tech Institute-Westboro                             21500
# Spa Tech Institute-Westbrook                            21500
# Spalding University                                     41700
# ...                                                       ...
# Studio Academy of Beauty                                  NaN
# Studio Jewelers                             PrivacySuppressed
# Stylemaster College of Hair Design                      17000
# Styles and Profiles Beauty College          PrivacySuppressed
# Styletrends Barber and Hairstyling Academy  PrivacySuppressed
#
#                                            GRAD_DEBT_MDN_SUPP
# INSTNM
# Spa Tech Institute-Ipswich                               6333
# Spa Tech Institute-Plymouth                              6333
# Spa Tech Institute-Westboro                              6333
# Spa Tech Institute-Westbrook                             6333
# Spalding University                                     25000
# ...                                                       ...
# Studio Academy of Beauty                                 6333
# Studio Jewelers                             PrivacySuppressed
# Stylemaster College of Hair Design                      13320
# Styles and Profiles Beauty College          PrivacySuppressed
# Styletrends Barber and Hairstyling Academy             9495.5
#
# [201 rows x 26 columns]

# %%
# インデックスが逆方向にソートされていもOK
college = college.sort_index(ascending=False)
# is_monotonic_increasing又はis_monotonic_decreasingでソート方向が分かる
college.index.is_monotonic_decreasing
# Out:
# True

# %%
college.loc['E':'B']
# Out:
#                                                   CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Dyersburg State Community College            Dyersburg     TN   0.0      0.0
# Dutchess Community College                Poughkeepsie     NY   0.0      0.0
# Dutchess BOCES-Practical Nursing Program  Poughkeepsie     NY   0.0      0.0
# Durham Technical Community College              Durham     NC   0.0      0.0
# Durham Beauty Academy                           Durham     NC   0.0      0.0
# ...                                                ...    ...   ...      ...
# Bacone College                                Muskogee     OK   0.0      0.0
# Babson College                               Wellesley     MA   0.0      0.0
# BJ's Beauty & Barber College                    Auburn     WA   0.0      0.0
# BIR Training Center                            Chicago     IL   0.0      0.0
# B M Spurr School of Practical Nursing        Glen Dale     WV   0.0      0.0
#
#                                           WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Dyersburg State Community College               0.0         0       NaN
# Dutchess Community College                      0.0         0       NaN
# Dutchess BOCES-Practical Nursing Program        0.0         0       NaN
# Durham Technical Community College              0.0         0       NaN
# Durham Beauty Academy                           0.0         0       NaN
# ...                                             ...       ...       ...
# Bacone College                                  0.0         1     398.0
# Babson College                                  0.0         0     615.0
# BJ's Beauty & Barber College                    0.0         0       NaN
# BIR Training Center                             0.0         0       NaN
# B M Spurr School of Practical Nursing           0.0         0       NaN
#
#                                           SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# Dyersburg State Community College              NaN           0.0  2001.0
# Dutchess Community College                     NaN           0.0  6885.0
# Dutchess BOCES-Practical Nursing Program       NaN           0.0   155.0
# Durham Technical Community College             NaN           0.0  4769.0
# Durham Beauty Academy                          NaN           0.0    78.0
# ...                                            ...           ...     ...
# Bacone College                               428.0           0.0   939.0
# Babson College                               660.0           0.0  2107.0
# BJ's Beauty & Barber College                   NaN           0.0    28.0
# BIR Training Center                            NaN           0.0  2132.0
# B M Spurr School of Practical Nursing          NaN           0.0    31.0
#
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Dyersburg State Community College             0.7266      0.2139     0.0240
# Dutchess Community College                    0.6003      0.1361     0.1801
# Dutchess BOCES-Practical Nursing Program      0.4903      0.3419     0.0774
# Durham Technical Community College            0.3080      0.4611     0.1126
# Durham Beauty Academy                         0.0385      0.9231     0.0000
# ...                                              ...         ...        ...
# Bacone College                                0.1917      0.3099     0.0895
# Babson College                                0.3863      0.0479     0.0973
# BJ's Beauty & Barber College                  0.5000      0.0000     0.1429
# BIR Training Center                           0.1201      0.8452     0.0220
# B M Spurr School of Practical Nursing         1.0000      0.0000     0.0000
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Dyersburg State Community College             0.0040     0.0035     0.0000
# Dutchess Community College                    0.0182     0.0022     0.0007
# Dutchess BOCES-Practical Nursing Program      0.0258     0.0000     0.0065
# Durham Technical Community College            0.0451     0.0048     0.0019
# Durham Beauty Academy                         0.0128     0.0128     0.0000
# ...                                              ...        ...        ...
# Bacone College                                0.0288     0.2556     0.0053
# Babson College                                0.1144     0.0019     0.0005
# BJ's Beauty & Barber College                  0.2143     0.0000     0.0000
# BIR Training Center                           0.0127     0.0000     0.0000
# B M Spurr School of Practical Nursing         0.0000     0.0000     0.0000
#
#                                           UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Dyersburg State Community College            0.0185    0.0010     0.0085
# Dutchess Community College                   0.0446    0.0129     0.0049
# Dutchess BOCES-Practical Nursing Program     0.0581    0.0000     0.0000
# Durham Technical Community College           0.0182    0.0025     0.0457
# Durham Beauty Academy                        0.0000    0.0000     0.0128
# ...                                             ...       ...        ...
# Bacone College                               0.0298    0.0000     0.0895
# Babson College                               0.0233    0.2682     0.0603
# BJ's Beauty & Barber College                 0.0714    0.0000     0.0714
# BIR Training Center                          0.0000    0.0000     0.0000
# B M Spurr School of Practical Nursing        0.0000    0.0000     0.0000
#
#                                           PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Dyersburg State Community College           0.4423         1   0.4921
# Dutchess Community College                  0.3312         1   0.2464
# Dutchess BOCES-Practical Nursing Program    0.7548         1   0.5294
# Durham Technical Community College          0.6905         1   0.4495
# Durham Beauty Academy                       0.0000         1   0.5746
# ...                                            ...       ...      ...
# Bacone College                              0.1140         1   0.9392
# Babson College                              0.0000         1   0.1709
# BJ's Beauty & Barber College                0.0000         1   0.5192
# BIR Training Center                         0.1806         0   0.6700
# B M Spurr School of Practical Nursing       0.0000         1   0.4722
#
#                                           PCTFLOAN  UG25ABV  \
# INSTNM
# Dyersburg State Community College           0.2493   0.3097
# Dutchess Community College                  0.1936   0.1806
# Dutchess BOCES-Practical Nursing Program    0.6275   0.5430
# Durham Technical Community College          0.1796   0.5961
# Durham Beauty Academy                       0.8134   0.4000
# ...                                            ...      ...
# Bacone College                              0.8920   0.1648
# Babson College                              0.3727   0.0090
# BJ's Beauty & Barber College                0.6154   0.2917
# BIR Training Center                         0.6998   0.6741
# B M Spurr School of Practical Nursing       0.0000   0.4444
#
#                                             MD_EARN_WNE_P10 GRAD_DEBT_MDN_SUPP
# INSTNM
# Dyersburg State Community College                     26800               7475
# Dutchess Community College                            32500              10250
# Dutchess BOCES-Practical Nursing Program              36500               9500
# Durham Technical Community College                    27200            11069.5
# Durham Beauty Academy                     PrivacySuppressed              15332
# ...                                                     ...                ...
# Bacone College                                        29700              26350
# Babson College                                        86700              27000
# BJ's Beauty & Barber College                            NaN  PrivacySuppressed
# BIR Training Center                       PrivacySuppressed              15394
# B M Spurr School of Practical Nursing     PrivacySuppressed  PrivacySuppressed
#
# [1411 rows x 26 columns]
